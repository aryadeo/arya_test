# %% [markdown]
# <a href="https://colab.research.google.com/github/aryadeo/python_basics/blob/master/Matplotlib_pyplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Date:05.11.2019
#
# ![Logo](https://drive.google.com/uc?id=1hoc1cbBcGYfIxP8gcT7v3yKPFf5jeyY8)
#
#
# Notebook for Matplotlib.pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #Miscelleneous and Trials

# %%
fig = plt.figure()  # an empty figure with no axes
#plt.show()
fig.suptitle('No axes on this figure')  # Add a title so we know which it is

fig, ax_lst = plt.subplots(1, 1)  # a figure with a 2x2 grid of Axes

# %%
a_test=np.random.random((2,2))
print(a_test)
# Out:
# [[0.64576338 0.87008241]
#  [0.17176376 0.09482304]]

# %%
plt.scatter?

# %%
a_test_1=np.random.random()
print(a_test_1)
# Out:
# 0.010904058337273703

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100
#There's a convenient way for plotting objects with labelled data (i.e.data that can be accessed by index ``obj['y']``). 
#Instead of giving bthe data in *x* and *y*, you can provide the object in the *data* parameter and just give the labels for *x* and *y*::
#plot('xlabel', 'ylabel', data=obj)
plt.scatter('a', 'b',s='c',c='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
plt.hist?

# %% [markdown]
# #Basics of pyplot

# %%
#example of auto indexing
plt.plot([1,2,3,4])
plt.show()

# %%
x=np.arange(10)
y=np.linspace(0,1,num=10)
plt.plot(x,y,'ro')
plt.title('sample plot')
plt.xlabel('index')
plt.ylabel('value')
plt.show()

# %%
#multiple plot from a single command
x=np.linspace(0,10,360)
y=np.cos(2*np.pi*1*x)
y2=np.sin(2*np.pi*1*x)
plt.plot(x,y,'ro',x,y2,'b--')
plt.show()
